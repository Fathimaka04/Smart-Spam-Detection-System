# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import  MultinomialNB
import pickle
data={
    "Message":["Win cash now","How are you","Free recharge","Come to class"],
    "Label":["Spam","Ham","Spam","Ham"]
}
df=pd.DataFrame(data)
x=df["Message"]
y=df["Label"]
vectorizer=CountVectorizer()
vectorizer.fit(x)
print(vectorizer.vocabulary_)
x_vector=vectorizer.transform(x)
model=MultinomialNB()
model.fit(x_vector,y)
text_message=["how are you"]
test_ve=vectorizer.transform(text_message)
print(model.predict(test_ve))
pickle.dump(model,open("spam_model.pkl","wb"))
pickle.dump(vectorizer,open("vectorizer.pkl","wb"))
# Out:
# {'win': 9, 'cash': 1, 'now': 6, 'how': 5, 'are': 0, 'you': 10, 'free': 4, 'recharge': 7, 'come': 3, 'to': 8, 'class': 2}
# ['Ham']
